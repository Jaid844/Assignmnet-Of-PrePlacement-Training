# %%
class TreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        self.previous = None  # DLL previous pointer
        self.next = None  # DLL next pointer


def convertToDLL(root):
    if root is None:
        return None

    # Convert the left subtree
    leftHead = convertToDLL(root.left)

    # Find the inorder predecessor (rightmost node) in the left subtree
    predecessor = leftHead
    if predecessor:
        while predecessor.next:
            predecessor = predecessor.next

    # Set the next and previous pointers
    if leftHead:
        predecessor.next = root
        root.previous = predecessor

    # Convert the right subtree
    rightHead = convertToDLL(root.right)

    # Set the next and previous pointers
    if rightHead:
        rightHead.previous = root
        root.next = rightHead

    return leftHead if leftHead else root


# Example usage:
# Create a binary tree
root = TreeNode(4)
root.left = TreeNode(2)
root.right = TreeNode(6)
root.left.left = TreeNode(1)
root.left.right = TreeNode(3)
root.right.left = TreeNode(5)
root.right.right = TreeNode(

# %%
A Given a binary tree, the task is to flip the binary tree towards the right direction that is clockwise. See the below examples to see the transformation.

In the flip operation, the leftmost node becomes the root of the flipped tree and its parent becomes its right child and the right sibling becomes its left child and the same should be done for all left most nodes recursively.

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def flipBinaryTree(root):
    # Base case: if root is None or it does not have any children, return the root as is
    if root is None or (root.left is None and root.right is None):
        return root

    # Recursively flip the left and right subtrees
    flipped_left = flipBinaryTree(root.left)
    flipped_right = flipBinaryTree(root.right)

    # Swap the left and right children of the current root
    root.left = flipped_right
    root.right = flipped_left

    return root

# %%
<aside>
💡 Question-3:

Given a binary tree, print all its root-to-leaf paths without using recursion. For example, consider the following Binary Tree.

</aside>

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


def printRootToLeafPaths(root):
    if root is None:
        return

    stack = [(root, str(root.val))]

    while stack:
        node, path = stack.pop()

        if node.left is None and node.right is None:
            print(path)  # Print the path when reaching a leaf node

        if node.right:
            stack.append((node.right, path + "->" + str(node.right.val)))

        if node.left:
            stack.append((node.left, path + "->" + str(node.left.val)))


# Example usage
root = TreeNode(6)
root.left = TreeNode(3)
root.right = TreeNode(5)
root.left.left = TreeNode(2)
root.left.right = TreeNode(5)
root.right.right = TreeNode(4)
root.left.right.left = TreeNode(7)
root.left.right.right = TreeNode(4)

printRootToLeafPaths(root)

# %%
Given Preorder, Inorder and Postorder traversals of some tree. Write a program to check if they all are of the same tree.

**Examples:**

Input : 

        Inorder -> 4 2 5 1 3
        Preorder -> 1 2 4 5 3
        Postorder -> 4 5 2 3 1
Output : 

Yes
Explanation : 

All of the above three traversals are of
the same tree

# %%
def isSameTree(preorder, inorder, postorder):
    # Check if lengths of the lists are equal
    if len(preorder) != len(inorder) or len(inorder) != len(postorder):
        return False

    # Check if all three lists are empty (representing empty trees)
    if len(preorder) == 0 and len(inorder) == 0 and len(postorder) == 0:
        return True

    # Check if the first elements of the lists are equal
    if preorder[0] != inorder[0] or inorder[0] != postorder[-1]:
        return False

    # Find the root value from the first element of the preorder list
    root = preorder[0]

    # Find the index of the root value in the inorder list
    root_index = inorder.index(root)

    # Split the inorder list into left and right subtrees
    inorder_left = inorder[:root_index]
    inorder_right = inorder[root_index + 1:]

    # Split the preorder and
